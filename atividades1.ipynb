# %% [markdown]
# Exercício 1: Crie um programa que mostre na tela

# %%
a = "Eu estou aprendendo Python"
print(a)
# Out:
# Eu estou aprendendo Python

# %%
nome_do_aluno = "Ana"
idade_do_aluno = "18"
print("Meu nome é", nome_do_aluno, "e tenho", idade_do_aluno)
# Out:
# Meu nome é Ana e tenho 18

# %%
a = "Meu nome é Maria"
b = "Eu moro em Recife"
print(a) 
print(b)
# Out:
# Meu nome é Maria
# Eu moro em Recife

# %%
cidade = "Salvador"
estado = "BA"
pais = "Brasil"

print("Eu Moro em " + cidade + " - " + estado + ", " +  pais)
# Out:
# Eu Moro em Salvador - BA, Brasil

# %%
nome = input("Qual é o seu nome? ")

cidade = input("Em qual cidade você mora? ")

print("Olá {}, você mora em {}".format(nome, cidade))
# Out:
# Qual é o seu nome?  Luiz
# Em qual cidade você mora?  Goiânia
# Olá Luiz , você mora em Goiânia
